# %%
from google.colab import drive
drive.mount ('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Math_6397/CH01
# Out:
# /content/drive/MyDrive/Math_6397/CH01

# %%
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize'] = [16, 8]


A = imread(os.path.join('..','DATA','dog.jpg'))
X = np.mean(A, -1); # Convert RGB to grayscale

img = plt.imshow(X)
img.set_cmap('gray')
plt.axis('off')
plt.show()

# %%
Xt=np.fft.fft2(X)
Xtsort=np.sort(np.abs(Xt.reshape(-1)))

for keep in (0.1, 0.05, 0.01, 0.002):
  threshold= Xtsort[int(np.floor((1-keep)*len(Xtsort)))]
  ind = np.abs(Xt)>threshold
  Btlow = Xt*ind
  Blow = np.fft.ifft2(Btlow).real
  error=X-Blow
  plt.figure()
  plt.imshow(Blow,cmap='gray')
  plt.axis('off')
  plt.title('Compressed image: ratio = ' +str(100/(keep*100))+ '%')

# %%
for keep in (0.1, 0.05, 0.01, 0.002):
  threshold= Xtsort[int(np.floor((1-keep)*len(Xtsort)))]
  ind = np.abs(Xt)>threshold
  Btlow = Xt*ind
  Blow = np.fft.ifft2(Btlow).real
  error=X-Blow
  plt.figure()
  plt.plot(error[0])
  plt.show
  plt.title('Error: ratio = ' +str(100/(keep*100))+ '%')

# %%
np.shape(error[])
# Out:
# (1500,)
